# %% [markdown]
# ### PANDAS DATAFRAME

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\pk161\OneDrive\ドキュメント\data.csv')

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(df)
# Out:
# 195

# %%
df.shape
# Out:
# (195, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
len(df.columns)
# Out:
# 5

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.tail(10)
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 185  Virgin Islands (U.S.)         VIR     10.700           45.3
# 186                Vietnam         VNM     15.537           43.9
# 187                Vanuatu         VUT     26.739           11.3
# 188     West Bank and Gaza         PSE     30.394           46.6
# 189                  Samoa         WSM     26.172           15.3
# 190            Yemen, Rep.         YEM     32.947           20.0
# 191           South Africa         ZAF     20.850           46.5
# 192       Congo, Dem. Rep.         COD     42.394            2.2
# 193                 Zambia         ZMB     40.471           15.4
# 194               Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 185          High income
# 186  Lower middle income
# 187  Lower middle income
# 188  Lower middle income
# 189  Lower middle income
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# ...

# %%
df.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df.describe().transpose()
# Out:
#                count       mean        std  min      25%    50%      75%  \
# BirthRate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# InternetUsers  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                    max
# BirthRate      49.6610
# InternetUsers  96.5468

# %%
# renaming columns

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
df.columns=['A','B','C','D','E']

# %%
df.head()
# Out:
#                       A    B       C     D                    E
# 0                 Aruba  ABW  10.244  78.9          High income
# 1           Afghanistan  AFG  35.253   5.9           Low income
# 2                Angola  AGO  45.985  19.1  Upper middle income
# 3               Albania  ALB  12.877  57.2  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0          High income

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns=['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[10:20]
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 10              Azerbaijan         AZE     18.300       58.70000
# 11                 Burundi         BDI     44.151        1.30000
# 12                 Belgium         BEL     11.200       82.17020
# 13                   Benin         BEN     36.440        4.90000
# 14            Burkina Faso         BFA     40.551        9.10000
# 15              Bangladesh         BGD     20.142        6.63000
# 16                Bulgaria         BGR      9.200       53.06150
# 17                 Bahrain         BHR     15.040       90.00004
# 18            Bahamas, The         BHS     15.339       72.00000
# 19  Bosnia and Herzegovina         BIH      9.062       57.79000
#
#             IncomeGroup
# 10  Upper middle income
# 11           Low income
# 12          High income
# 13           Low income
# 14           Low income
# 15  Lower middle income
# 16  Upper middle income
# 17          High income
# ...

# %%
df[20:50:5]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 20     Belarus         BLR     12.500          54.17  Upper middle income
# 25    Barbados         BRB     12.188          73.00          High income
# 30      Canada         CAN     10.900          85.80          High income
# 35    Cameroon         CMR     37.236           6.40  Lower middle income
# 40  Costa Rica         CRI     15.022          45.96  Upper middle income
# 45     Germany         DEU      8.500          84.17          High income

# %%
df[10:200:10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# 110      Moldova         MDA     12.141      45.000000  Lower middle income
# ...

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[::-10]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715        18.5000
# 184         Venezuela, RB         VEN     19.842        54.9000
# 174   Trinidad and Tobago         TTO     14.590        63.8000
# 164             Swaziland         SWZ     30.093        24.7000
# 154          Sierra Leone         SLE     36.729         1.7000
# 144      French Polynesia         PYF     16.393        56.8000
# 134                  Oman         OMN     20.419        66.4500
# 124              Malaysia         MYS     16.805        66.9700
# 114        Macedonia, FYR         MKD     11.222        65.2400
# 104               Lesotho         LSO     28.738         5.0000
# 94               Kiribati         KIR     29.044        11.5000
# 84                Iceland         ISL     13.400        96.5468
# 74   Hong Kong SAR, China         HKG      7.900        74.2000
# 64                 Guinea         GIN     37.337         1.6000
# ...

# %%
df[::]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[::25]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244      78.900000          High income
# 25     Barbados         BRB     12.188      73.000000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 75     Honduras         HND     21.593      17.800000  Lower middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 125     Namibia         NAM     29.937      13.900000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income
# 175     Tunisia         TUN     19.800      43.800000  Upper middle income

# %%
df[::20]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244        78.9000          High income
# 20      Belarus         BLR     12.500        54.1700  Upper middle income
# 40   Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60        Gabon         GAB     30.555         9.2000  Upper middle income
# 80        India         IND     20.291        15.1000  Lower middle income
# 100       Libya         LBY     21.425        16.5000  Upper middle income
# 120  Mozambique         MOZ     39.705         5.4000           Low income
# 140      Poland         POL      9.600        62.8492          High income
# 160    Suriname         SUR     18.455        37.4000  Upper middle income
# 180     Uruguay         URY     14.374        57.6900          High income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
df['CountryName'].head(10)
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# 5               Argentina
# 6                 Armenia
# 7     Antigua and Barbuda
# 8               Australia
# 9                 Austria
# Name: CountryName, dtype: object

# %%
df['CountryCode'].head(10)
# Out:
# 0    ABW
# 1    AFG
# 2    AGO
# 3    ALB
# 4    ARE
# 5    ARG
# 6    ARM
# 7    ATG
# 8    AUS
# 9    AUT
# Name: CountryCode, dtype: object

# %%
df['BirthRate'].head(10)
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# 5    17.716
# 6    13.308
# 7    16.447
# 8    13.200
# 9     9.400
# Name: BirthRate, dtype: float64

# %%
df['IncomeGroup'].head(10)
# Out:
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# 8            High income
# 9            High income
# Name: IncomeGroup, dtype: object

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df[['CountryName','CountryCode']]
# Out:
#               CountryName CountryCode
# 0                   Aruba         ABW
# 1             Afghanistan         AFG
# 2                  Angola         AGO
# 3                 Albania         ALB
# 4    United Arab Emirates         ARE
# ..                    ...         ...
# 190           Yemen, Rep.         YEM
# 191          South Africa         ZAF
# 192      Congo, Dem. Rep.         COD
# 193                Zambia         ZMB
# 194              Zimbabwe         ZWE
#
# [195 rows x 2 columns]

# %%
df[['CountryName','BirthRate']]
# Out:
#               CountryName  BirthRate
# 0                   Aruba     10.244
# 1             Afghanistan     35.253
# 2                  Angola     45.985
# 3                 Albania     12.877
# 4    United Arab Emirates     11.044
# ..                    ...        ...
# 190           Yemen, Rep.     32.947
# 191          South Africa     20.850
# 192      Congo, Dem. Rep.     42.394
# 193                Zambia     40.471
# 194              Zimbabwe     35.715
#
# [195 rows x 2 columns]

# %%
df[['CountryName','BirthRate','InternetUsers']].head()
# Out:
#             CountryName  BirthRate  InternetUsers
# 0                 Aruba     10.244           78.9
# 1           Afghanistan     35.253            5.9
# 2                Angola     45.985           19.1
# 3               Albania     12.877           57.2
# 4  United Arab Emirates     11.044           88.0

# %%
df[['InternetUsers','IncomeGroup']].head()
# Out:
#    InternetUsers          IncomeGroup
# 0           78.9          High income
# 1            5.9           Low income
# 2           19.1  Upper middle income
# 3           57.2  Upper middle income
# 4           88.0          High income

# %%
df[['CountryName','IncomeGroup']][10:20]
# Out:
#                CountryName          IncomeGroup
# 10              Azerbaijan  Upper middle income
# 11                 Burundi           Low income
# 12                 Belgium          High income
# 13                   Benin           Low income
# 14            Burkina Faso           Low income
# 15              Bangladesh  Lower middle income
# 16                Bulgaria  Upper middle income
# 17                 Bahrain          High income
# 18            Bahamas, The          High income
# 19  Bosnia and Herzegovina  Upper middle income

# %%
df[['CountryName','InternetUsers']][10:20]
# Out:
#                CountryName  InternetUsers
# 10              Azerbaijan       58.70000
# 11                 Burundi        1.30000
# 12                 Belgium       82.17020
# 13                   Benin        4.90000
# 14            Burkina Faso        9.10000
# 15              Bangladesh        6.63000
# 16                Bulgaria       53.06150
# 17                 Bahrain       90.00004
# 18            Bahamas, The       72.00000
# 19  Bosnia and Herzegovina       57.79000

# %%
df['CountryName'][10:50]
# Out:
# 10                  Azerbaijan
# 11                     Burundi
# 12                     Belgium
# 13                       Benin
# 14                Burkina Faso
# 15                  Bangladesh
# 16                    Bulgaria
# 17                     Bahrain
# 18                Bahamas, The
# 19      Bosnia and Herzegovina
# 20                     Belarus
# 21                      Belize
# 22                     Bermuda
# 23                     Bolivia
# 24                      Brazil
# 25                    Barbados
# 26           Brunei Darussalam
# 27                      Bhutan
# 28                    Botswana
# 29    Central African Republic
# 30                      Canada
# 31                 Switzerland
# 32                       Chile
# 33                       China
# 34               Cote d'Ivoire
# 35                    Cameroon
# 36                 Congo, Rep.
# 37                    Colombia
# 38                     Comoros
# 39                  Cabo Verde
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.BirthRate*df.InternetUsers
# Out:
# 0      808.2516
# 1      207.9927
# 2      878.3135
# 3      736.5644
# 4      971.8720
#          ...
# 190    658.9400
# 191    969.5250
# 192     93.2668
# 193    623.2534
# 194    660.7275
# Length: 195, dtype: float64

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df['a']=df.BirthRate*df.InternetUsers
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup         a
# 0            High income  808.2516
# 1             Low income  207.9927
# 2    Upper middle income  878.3135
# 3    Upper middle income  736.5644
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup         a
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
df['b']=df.BirthRate+df.InternetUsers
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup         a       b
# 0          High income  808.2516  89.144
# 1           Low income  207.9927  41.153
# 2  Upper middle income  878.3135  65.085
# 3  Upper middle income  736.5644  70.077
# 4          High income  971.8720  99.044

# %%
df['c']=df.BirthRate-df.InternetUsers
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup         a       b       c
# 0          High income  808.2516  89.144 -68.656
# 1           Low income  207.9927  41.153  29.353
# 2  Upper middle income  878.3135  65.085  26.885
# 3  Upper middle income  736.5644  70.077 -44.323
# 4          High income  971.8720  99.044 -76.956

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup         a       b       c
# 0          High income  808.2516  89.144 -68.656
# 1           Low income  207.9927  41.153  29.353
# 2  Upper middle income  878.3135  65.085  26.885
# 3  Upper middle income  736.5644  70.077 -44.323
# 4          High income  971.8720  99.044 -76.956

# %%
df = df.drop('c',axis=1)
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup         a       b
# 0          High income  808.2516  89.144
# 1           Low income  207.9927  41.153
# 2  Upper middle income  878.3135  65.085
# 3  Upper middle income  736.5644  70.077
# 4          High income  971.8720  99.044

# %%
df= df.drop('a',axis=1)
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup       b
# 0          High income  89.144
# 1           Low income  41.153
# 2  Upper middle income  65.085
# 3  Upper middle income  70.077
# 4          High income  99.044

# %%
df=df.drop('b',axis=1)
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.columns[4]
# Out:
# 'IncomeGroup'

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.InternetUsers<5
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
Filter=df.InternetUsers<5

# %%
Filter
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[Filter]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 13                      Benin         BEN     36.440            4.9
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 117                   Myanmar         MMR     18.119            1.6
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# ...

# %%
df.BirthRate<10
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: BirthRate, Length: 195, dtype: bool

# %%
Filter1=df.BirthRate>30

# %%
Filter1
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191    False
# 192     True
# 193     True
# 194     True
# Name: BirthRate, Length: 195, dtype: bool

# %%
df[Filter1]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 2                      Angola         AGO     45.985          19.10
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 60                      Gabon         GAB     30.555           9.20
# ...

# %%
Filter & Filter1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192     True
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
df[Filter & Filter1]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 13                      Benin         BEN     36.440            4.9
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# 156                   Somalia         SOM     43.891            1.5
# ...

# %%
df[(df.InternetUsers<5) & (df.BirthRate>30)]
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 11                    Burundi         BDI     44.151            1.3
# 13                      Benin         BEN     36.440            4.9
# 29   Central African Republic         CAF     34.076            3.5
# 52                    Eritrea         ERI     34.800            0.9
# 55                   Ethiopia         ETH     32.925            1.9
# 64                     Guinea         GIN     37.337            1.6
# 66              Guinea-Bissau         GNB     37.503            3.1
# 99                    Liberia         LBR     35.521            3.2
# 111                Madagascar         MDG     34.686            3.0
# 115                      Mali         MLI     44.138            3.5
# 127                     Niger         NER     49.661            1.7
# 154              Sierra Leone         SLE     36.729            1.7
# 156                   Somalia         SOM     43.891            1.5
# ...

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.IncomeGroup.unique()
# Out:
# array(['High income', 'Low income', 'Upper middle income',
#        'Lower middle income'], dtype=object)

# %%
df[df.IncomeGroup=='Low income']
# Out:
#                   CountryName CountryCode  BirthRate  InternetUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 64                     Guinea         GIN     37.337           1.60
# 65                Gambia, The         GMB     42.525          14.00
# 66              Guinea-Bissau         GNB     37.503           3.10
# 77                      Haiti         HTI     25.345          10.60
# 93                   Cambodia         KHM     24.462           6.80
# ...

# %%
df[df.IncomeGroup=='High income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
df[df.IncomeGroup=='Upper middle income']
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 2                            Angola         AGO     45.985      19.100000
# 3                           Albania         ALB     12.877      57.200000
# 10                       Azerbaijan         AZE     18.300      58.700000
# 16                         Bulgaria         BGR      9.200      53.061500
# 19           Bosnia and Herzegovina         BIH      9.062      57.790000
# 20                          Belarus         BLR     12.500      54.170000
# 21                           Belize         BLZ     23.092      33.600000
# 24                           Brazil         BRA     14.931      51.040000
# 28                         Botswana         BWA     25.267      15.000000
# 33                            China         CHN     12.100      45.800000
# 37                         Colombia         COL     16.076      51.700000
# 40                       Costa Rica         CRI     15.022      45.960000
# ...

# %%
df[df.IncomeGroup=='Lower middle income']
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  \
# 6                  Armenia         ARM     13.308        41.9000
# 15              Bangladesh         BGD     20.142         6.6300
# 23                 Bolivia         BOL     24.236        36.9400
# 27                  Bhutan         BTN     18.134        29.9000
# 34           Cote d'Ivoire         CIV     37.320         8.4000
# 35                Cameroon         CMR     37.236         6.4000
# 36             Congo, Rep.         COG     37.011         6.6000
# 39              Cabo Verde         CPV     21.625        37.5000
# 46                Djibouti         DJI     25.486         9.5000
# 51        Egypt, Arab Rep.         EGY     28.032        29.4000
# 59   Micronesia, Fed. Sts.         FSM     23.511        27.8000
# 62                 Georgia         GEO     13.332        43.3000
# 63                   Ghana         GHA     33.131        12.3000
# ...

# %%
 import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize']=8,4

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
vis1 = sns.distplot(df["InternetUsers"])
plt.show()

# %%
vis1 = sns.distplot(df["InternetUsers"],bins=10)
plt.show()

# %%
vis2 = sns.boxplot(data=df, x="IncomeGroup",y='BirthRate')
plt.show()

# %%
vis3 = sns.lmplot(data=df,x="InternetUsers",y="BirthRate",fit_reg=False)
plt.show()

# %%
vis4 = sns.lmplot(data=df,x="InternetUsers",y="BirthRate")
plt.show()

# %%
vis5 = sns.lmplot(data=df,x="InternetUsers",y="BirthRate",fit_reg=False,hue="IncomeGroup")
plt.show()

# %%
vis5=sns.lmplot(data=df,x="InternetUsers",y="BirthRate",fit_reg=False,hue='IncomeGroup', height = 10)
plt.show()

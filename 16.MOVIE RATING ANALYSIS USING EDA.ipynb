# %% [markdown]
# # Movie Rating Analytics

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\pk161'

# %%
movies=pd.read_csv(r'C:\Users\pk161\OneDrive\ドキュメント\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies['AudienceRating']
# Out:
# 0      81
# 1      44
# 2      52
# 3      84
# 4      70
#        ..
# 554    36
# 555    52
# 556    73
# 557    87
# 558    42
# Name: AudienceRating, Length: 559, dtype: int64

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film=movies.Film.astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
movies
# Out:
#                       Film      Genre  CriticRating  AudienceRating  \
# 0    (500) Days of Summer      Comedy            87              81
# 1              10,000 B.C.  Adventure             9              44
# 2               12 Rounds      Action            30              52
# 3                127 Hours  Adventure            93              84
# 4                17 Again      Comedy            55              70
# ..                     ...        ...           ...             ...
# 554          Your Highness     Comedy            26              36
# 555        Youth in Revolt     Comedy            68              52
# 556                 Zodiac   Thriller            89              73
# 557            Zombieland      Action            90              87
# 558              Zookeeper     Comedy            14              42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating')

# %%
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind="hex")
plt.show()

# %%
j = sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind="scatter")
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticRating',y='AudienceRating',kind="reg")

# %%
plt.show()

# %%
# histograms
m1=sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
m2=sns.distplot(movies.AudienceRating,bins=15)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
n1=plt.hist(movies.AudienceRating,bins=15)
plt.show()

# %%
sns.set_style('white')
n1=plt.hist(movies.AudienceRating,bins=20)
plt.show()

# %%
n1=plt.hist(movies.CriticRating,bins=20)

# %%
plt.show()

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies.Genre)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Comedy'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Adventure'].BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.Genre=='Comedy'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre=='Action'].BudgetMillions,bins=20)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions,bins=20)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
         movies[movies.Genre=='Drama'].BudgetMillions,\
         movies[movies.Genre=='Thirller'].BudgetMillions,\
         movies[movies.Genre=='Horror'].BudgetMillions],
         bins=20, stacked=True)
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].BudgetMillions,\
         movies[movies.Genre=='Drama'].BudgetMillions,\
         movies[movies.Genre=='Thirller'].BudgetMillions,\
         movies[movies.Genre=='Horror'].BudgetMillions],
         bins=20, stacked=False)
plt.show()

# %%
# it prints genre types in movies
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
# it prints all movies genre
for gen in movies.Genre:
    print(gen)
# Out:
# Comedy
# Adventure
# Action
# Adventure
# Comedy
# Action
# Comedy
# Horror
# Comedy
# Comedy
# Drama
# Drama
# Horror
# Drama
# Comedy
# Action
# Romance
# Comedy
# Drama
# Adventure
# Horror
# Adventure
# Comedy
# Drama
# Adventure
# Thriller
# Drama
# Drama
# Horror
# Action
# Action
# Comedy
# Adventure
# Action
# Comedy
# Comedy
# Action
# Comedy
# Comedy
# Action
# Action
# Comedy
# Romance
# Comedy
# Comedy
# Action
# Adventure
# Drama
# Comedy
# Action
# Comedy
# Comedy
# Action
# Drama
# Comedy
# Drama
# Drama
# Comedy
# Action
# Horror
# Action
# Comedy
# Drama
# Action
# Comedy
# Adventure
# Action
# Action
# Adventure
# Action
# Action
# Comedy
# Thriller
# Action
# Drama
# Comedy
# Action
# Action
# Romance
# Comedy
# Comedy
# Action
# Comedy
# Action
# Drama
# Comedy
# Action
# Comedy
# Horror
# Comedy
# Comedy
# Comedy
# Comedy
# Comedy
# Action
# Thriller
# Drama
# Horror
# Action
# Drama
# Horror
# Action
# Action
# Horror
# Comedy
# Thriller
# Action
# Comedy
# ...

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating')
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',\
                fit_reg=False)
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',hue='Genre',fit_reg=False)
plt.show()

# %%
plt.style.use('dark_background')
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',hue='Genre',fit_reg=False,height=10,aspect=1)
plt.show()

# %%
vis1=sns.lmplot(data=movies,x='CriticRating',y='AudienceRating',hue='Genre',fit_reg=False,height=8,aspect=1)
plt.show()

# %%
plt.style.use('default')

# %%
k1=sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating')
plt.show()

# %%
k1=sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade=True,shade_lowest=False,cmap='Reds')
plt.show()

# %%
k2=sns.kdeplot(data=movies,x='CriticRating',y='AudienceRating',shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k1=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',shade_lowest=False,cmap='Greens_r')
plt.show()

# %%
sns.set_style('dark')
k1=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating')
plt.show()

# %%
f,ax=plt.subplots(1,2)
plt.show()

# %%
g,ax=plt.subplots(1,3)
plt.show()

# %%
f,ax=plt.subplots(3,3,figsize=(11,8))
plt.show()

# %%
f,axis=plt.subplots(1,2,figsize=(11,8))
k1=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',ax=axis[1])
plt.show()

# %%
f,axis=plt.subplots(1,2,figsize=(11,8))
k1=sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',ax=axis[0])
k2=sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',ax=axis[1])
plt.show()

# %%
axis
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='CriticRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>],
#       dtype=object)

# %%
# box plots
b=sns.boxplot(data=movies,x='Genre',y='CriticRating')
plt.show()

# %%
b1=sns.boxplot(data=movies,x='Genre',y='AudienceRating')
plt.show()

# %%
b2=sns.boxplot(data=movies,x='Genre',y='BudgetMillions')
plt.show()

# %%
c=sns.violinplot(data=movies,x='Genre',y='CriticRating')
plt.show()

# %%
c1=sns.violinplot(data=movies,x='Genre',y='AudienceRating')
plt.show()

# %%
c2=sns.violinplot(data=movies,x='Genre',y='BudgetMillions')
plt.show()

# %%
c3=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')
plt.show()

# %%
c4=sns.violinplot(data=movies[movies.Genre=='Action'],x='Year',y='CriticRating')
plt.show()

# %%
c5=sns.violinplot(data=movies[movies.Genre=='Comedy'],x='Year',y='CriticRating')
plt.show()

# %%
c6=sns.violinplot(data=movies[movies.Genre=='Thriller'],x='Year',y='AudienceRating')
plt.show()

# %%
b3=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='CriticRating')
plt.show()

# %%
b3=sns.boxplot(data=movies[movies.Genre=='Drama'],x='Year',y='AudienceRating')
plt.show()

# %%
b4=sns.boxplot(data=movies[movies.Genre=='Action'],x='Year',y='CriticRating')
plt.show()

# %%
b4=sns.boxplot(data=movies[movies.Genre=='Action'],x='Year',y='AudienceRating')
plt.show()

# %%
b5=sns.boxplot(data=movies[movies.Genre=='Thriller'],x='Year',y='CriticRating')
plt.show()

# %%
b5=sns.boxplot(movies[movies.Genre=='Thriller'],x='Year',y='AudienceRating')
plt.show()

# %%
plt.style.use('default')

# %%
# creating a facetgrid
f=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
plt.show()

# %%
plt.style.use('dark_background')
plt.scatter(movies.CriticRating,movies.AudienceRating)
plt.show()

# %%
plt.style.use('dark_background')
g= sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'CriticRating','AudienceRating')
plt.show()

# %%
plt.style.use('default')
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'BudgetMillions')
plt.show()

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
abc=dict(s=50,linewidth=0.5,edgecolor='Black')
g=g.map(plt.scatter,'CriticRating','AudienceRating',**abc)
plt.show()
